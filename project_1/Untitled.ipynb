# %%
import pandas as pd

# %%
import pandas as pd
testa = pd.read_csv('a.csv')
testb = pd.read_csv('b.csv')
print(a['school'][4])
# Out:
# University of California ​Irvine

# %%
a['school'][4]
# Out:
# 'University of California \u200bIrvine'

# %%
testa.shape, testb.shape
# Out:
# ((24, 14), (9, 5))

# %%
def clean(name):
    name = name.replace('\u200b','').rstrip()
    return name

testa['school'] = testa['school'].map(clean)
print(testa['school'][2])

df = pd.merge(testa, testb, on='school')

df
# Out:
# University of Southern California
#    Unnamed: 0_x                                  school test_optional  \
# 0            24    University of California Los Angeles           Yes
# 1            33       University of California Berkeley      Yes (TB)
# 2            60         University of California Irvine      Yes (TB)
# 3            69  University of California Santa Barbara           Yes
# 4            72      University of California San Diego           Yes
# 5           108          University of California Davis           Yes
# 6           143     University of California Santa Cruz      Yes (TB)
# 7           160      University of California Riverside           Yes
# 8           269         University of California Merced           Yes
#
#            class_years                                     policy_details  \
# 0  2021 2022 2023 2024  The UC system has adopted a two-year test opti...
# 1  2021 2022 2023 2024  Cal has adopted a four-year test blind policy ...
# ...

# %%
df.shape
# Out:
# (9, 18)
